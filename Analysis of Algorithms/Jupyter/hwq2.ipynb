# %% [markdown]
# # Zach Macadam

# %% [markdown]
# # Homework 1: Question 2: Selection Sort

# %% [markdown]
# from IPython.display import Latex

# %%
def find_peak(arr):
    list_length = len(arr)
    if not arr:
        return []
    if list_length == 1:
        return [0]
    result = []
    if arr[0] > arr[1]:
        result.append(0)
    if list_length > 1:
        if arr[list_length - 2] < arr[list_length - 1]:
            result.append(list_length - 1)
    for i in range (0,list_length):
        if i+2 < list_length:
            if arr[i] < arr[i+1] and arr[i+1] > arr[i+2]:
                result.append(i+1)
    return(result)

print(find_peak([5,10,20,15]))
print(find_peak([10,20,15,2,23,90,67]))
print(find_peak([]))
print(find_peak([1]))
print(find_peak([1,2]))
print(find_peak([2,1]))
print(find_peak([2,1,2]))
print(find_peak([1,1]))
print(find_peak([2,2,1,1,3,3,1,1,-1,-1,0]))
# Out:
# [2]
# [1, 5]
# []
# [0]
# [1]
# [0]
# [0, 2]
# []
# [10]

# %% [markdown]
# ![Graph.JPG](attachment:Graph.JPG)

# %% [markdown]
# Slope = 370.7064807\
# Y-Intercept = 35139.52067\
# T(n) = c<sub>1</sub> + c<sub>2</sub> + c<sub>3</sub> + c<sub>4</sub> + c<sub>5</sub>n + c<sub>6</sub>(n-1) + c<sub>7</sub>\
# T(n) = (c<sub>5</sub> + c<sub>6</sub>)n - c<sub>6</sub> + (c<sub>1</sub> + c<sub>2</sub> + c<sub>3</sub> + c<sub>4</sub> + c<sub>7</sub>)\
# T(n) = an + b\
# T(n) = $\Theta$(n)
